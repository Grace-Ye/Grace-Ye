# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os 
print(os.getcwd())
# Out:
# /Users/gracey./Desktop/world-happiness-report

# %%
data_2015=pd.read_csv('2015.csv')
data_2015
data_2015=data_2015.drop(['Region','Standard Error','Dystopia Residual'],axis=1)
data_2015
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
data_2016=pd.read_csv('2016.csv')
data_2016
data_2016=data_2016.drop(['Region','Lower Confidence Interval','Upper Confidence Interval','Dystopia Residual'],axis=1)
data_2016
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0        Denmark               1            7.526                   1.44178
# 1    Switzerland               2            7.509                   1.52733
# 2        Iceland               3            7.501                   1.42666
# 3         Norway               4            7.498                   1.57744
# 4        Finland               5            7.413                   1.40598
# ..           ...             ...              ...                       ...
# 152        Benin             153            3.484                   0.39499
# 153  Afghanistan             154            3.360                   0.38227
# 154         Togo             155            3.303                   0.28123
# 155        Syria             156            3.069                   0.74719
# 156      Burundi             157            2.905                   0.06831
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
data_2017=pd.read_csv('2017.csv')
data_2017
data_2017=data_2017.drop(['Whisker.high','Whisker.low','Dystopia.Residual'],axis=1)
data_2017=data_2017.rename(columns={'Happiness.Rank':'Happiness Rank','Happiness.Score':'Happiness Score','Economy..GDP.per.Capita.':'Economy (GDP per Capita)','Health..Life.Expectancy.':'Health (Life Expectancy)','Trust..Government.Corruption.':'Trust (Government Corruption)'})
data_2017
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# ...

# %%
data_2018=pd.read_csv('2018.csv')
data_2018
data_2018=data_2018.rename(columns={'Country or region':'Country','Social support':'Family','Overall rank':'Happiness Rank','Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)','Healthy life expectancy':'Healthy (life expectancy)','Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})
data_2018
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      Economy (GDP per Capita)  Family  Healthy (life expectancy)  Freedom  \
# 0                       1.305   1.592                      0.874    0.681
# ...

# %%
data_2019=pd.read_csv('2019.csv')
data_2019
data_2019=data_2019.rename(columns={'Overall rank':'Happiness Rank','Country or region':'Country','Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)','Social support':'Family','Healthy life expectancy':'Healthy (life expectancy)','Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})
data_2019
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      Economy (GDP per Capita)  Family  Healthy (life expectancy)  Freedom  \
# 0                       1.340   1.587                      0.986    0.596
# ...

# %%
dataframe=[data_2015,data_2016,data_2017,data_2018,data_2019]
dataframe=pd.concat(dataframe)
dataframe['Health (Life Expectancy)']=dataframe['Health (Life Expectancy)'].fillna(0)
dataframe['Healthy (life expectancy)']=dataframe['Healthy (life expectancy)'].fillna(0)
dataframe['Life Expectancy']=dataframe['Health (Life Expectancy)']+dataframe['Healthy (life expectancy)']
dataframe=dataframe.drop(['Health (Life Expectancy)','Healthy (life expectancy)'],axis=1)
dataframe
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      Economy (GDP per Capita)   Family  Freedom  \
# 0                     1.39651  1.34951  0.66557
# 1                     1.30232  1.40223  0.62877
# 2                     1.32548  1.36058  0.64938
# ...

# %%
dataframe.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      782.000000       782.000000                782.000000  782.000000
# mean        78.698210         5.379018                  0.916047    1.078392
# std         45.182384         1.127456                  0.407340    0.329548
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         40.000000         4.509750                  0.606500    0.869363
# 50%         79.000000         5.322000                  0.982205    1.124735
# 75%        118.000000         6.189500                  1.236187    1.327250
# max        158.000000         7.769000                  2.096000    1.644000
#
#           Freedom  Trust (Government Corruption)  Generosity  Life Expectancy
# count  782.000000                     781.000000  782.000000       782.000000
# mean     0.411091                       0.125436    0.218576         0.612416
# ...

# %%
dataframe=dataframe.drop(['Country'],axis=1)
for column in dataframe.columns:
    plt.figure()
    sns.distplot(dataframe[column])

# %%
for column in dataframe.columns:
    plt.figure()
    sns.boxplot(dataframe[column],showmeans=True)

# %%
sns.lmplot(x='Trust (Government Corruption)',y='Happiness Rank',data=dataframe)

# %%
dataframe['log(Trust (Government Corruption))']=np.log(dataframe['Trust (Government Corruption)'])
dataframe['log(Happiness Score)']=np.log(dataframe['Happiness Score'])
dataframe
sns.lmplot(x='log(Trust (Government Corruption))',y='log(Happiness Score)',data=dataframe)
# Out:
# /Users/gracey./Downloads/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/gracey./Downloads/anaconda3/lib/python3.8/site-packages/numpy/core/function_base.py:153: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /Users/gracey./Downloads/anaconda3/lib/python3.8/site-packages/numpy/core/function_base.py:163: RuntimeWarning: invalid value encountered in add
#   y += start
# /Users/gracey./Downloads/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
Q1 = dataframe['Trust (Government Corruption)'].quantile(0.25)
Q3 = dataframe['Trust (Government Corruption)'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
df_filter = (dataframe['Trust (Government Corruption)'] >= Q1 - 1.5*IQR) & (dataframe['Trust (Government Corruption)'] <= Q3 + 1.5*IQR)
df_filter=dataframe.loc[df_filter]
df_filter
# Out:
# 0.10203
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)   Family  \
# 1                 2            7.561                   1.30232  1.40223
# 10               11            7.278                   1.22857  1.22393
# 11               12            7.226                   0.95578  1.23788
# 12               13            7.200                   1.33723  1.29704
# 13               14            7.187                   1.02054  0.91451
# ..              ...              ...                       ...      ...
# 150             151            3.380                   0.28700  1.16300
# 152             153            3.231                   0.47600  0.88500
# 153             154            3.203                   0.35000  0.51700
# 154             155            3.083                   0.02600  0.00000
# 155             156            2.853                   0.30600  0.57500
#
#      Freedom  Trust (Government Corruption)  Generosity  Life Expectancy  \
# ...

# %%
sns.lmplot(x='log(Trust (Government Corruption))',y='log(Happiness Score)',data=df_filter)
# Out:
# /Users/gracey./Downloads/anaconda3/lib/python3.8/site-packages/numpy/core/function_base.py:153: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /Users/gracey./Downloads/anaconda3/lib/python3.8/site-packages/numpy/core/function_base.py:163: RuntimeWarning: invalid value encountered in add
#   y += start
# /Users/gracey./Downloads/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
corrMatrix=dataframe.corr()
corrMatrix
sns.heatmap(corrMatrix,annot=True)
plt.show()

# %%
Y=dataframe['Happiness Score']
dataframe_feature=['Happiness Score','Economy (GDP per Capita)','Family','Freedom','Life Expectancy']
X=dataframe[dataframe_feature]
X.describe()
# Out:
#        Happiness Score  Economy (GDP per Capita)      Family     Freedom  \
# count       782.000000                782.000000  782.000000  782.000000
# mean          5.379018                  0.916047    1.078392    0.411091
# std           1.127456                  0.407340    0.329548    0.152880
# min           2.693000                  0.000000    0.000000    0.000000
# 25%           4.509750                  0.606500    0.869363    0.309768
# 50%           5.322000                  0.982205    1.124735    0.431000
# 75%           6.189500                  1.236187    1.327250    0.531000
# max           7.769000                  2.096000    1.644000    0.724000
#
#        Life Expectancy
# count       782.000000
# mean          0.612416
# std           0.248309
# min           0.000000
# 25%           0.440183
# 50%           0.647310
# 75%           0.808000
# max           1.141000

# %%
from sklearn.tree import DecisionTreeRegressor
happiness_model=DecisionTreeRegressor(random_state=1)
happiness_model.fit(X, Y)
X.head()
happiness_model.predict(X.head())
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427])

# %%
X.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  Freedom  \
# 0            7.587                   1.39651  1.34951  0.66557
# 1            7.561                   1.30232  1.40223  0.62877
# 2            7.527                   1.32548  1.36058  0.64938
# 3            7.522                   1.45900  1.33095  0.66973
# 4            7.427                   1.32629  1.32261  0.63297
#
#    Life Expectancy
# 0          0.94143
# 1          0.94784
# 2          0.87464
# 3          0.88521
# 4          0.90563

# %%
from sklearn.metrics import mean_absolute_error
predict_happiness_score=happiness_model.predict(X)
mean_absolute_error(Y,predict_happiness_score)
# Out:
# 1.8577543249125294e-09

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size=0.5,random_state = 0)
happiness_model = DecisionTreeRegressor()
happiness_model.fit(train_X, train_Y)
happiness_pred=happiness_model.predict(test_X)
mean_absolute_error(test_Y,happiness_pred)
# Out:
# 0.014094633390226657

# %%
plt.scatter(test_Y,happiness_pred)

# %%
from sklearn.tree import export_graphviz 
export_graphviz(happiness_model, out_file ='tree.dot', 
                feature_names =['Happiness Score','Economy','Family','Freedom','Life Expectancy'])

# %%
from sklearn.model_selection import train_test_split
#split data into train and test, we use train data to predict and test data to test
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size=0.5,random_state = 0)
#create a regression model 
happiness_model = DecisionTreeRegressor()
#treat model using train data
happiness_model.fit(train_X, train_Y)
happiness_pred=happiness_model.predict(test_X)
happiness_pred
# Out:
# array([5.525     , 6.901     , 6.343     , 7.119     , 3.775     ,
#        4.69500017, 4.374     , 5.04099989, 6.952     , 5.483     ,
#        6.52699995, 5.39499998, 3.34      , 5.129     , 2.905     ,
#        5.835     , 4.17999983, 4.377     , 4.793     , 5.358     ,
#        6.379     , 4.015     , 4.696     , 6.198     , 6.596     ,
#        7.226     , 5.7579999 , 7.526     , 3.656     , 6.91      ,
#        6.375     , 5.429     , 5.83799982, 3.36      , 7.226     ,
#        4.459     , 3.083     , 5.123     , 6.084     , 6.167     ,
#        4.512     , 5.97100019, 6.167     , 5.33599997, 7.31400006,
#        7.28399995, 5.64      , 5.274     , 5.915     , 3.656     ,
#        4.217     , 4.189     , 6.75      , 6.91      , 4.418     ,
#        5.04099989, 4.217     , 4.623     , 4.61      , 5.208     ,
#        7.632     , 3.083     , 6.985     , 6.65      , 6.028     ,
#        5.123     , 5.23000002, 3.46199989, 3.607     , 5.163     ,
# ...

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test_Y,happiness_pred)
# Out:
# 0.014094633390226657
